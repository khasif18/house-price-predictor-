# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Pandas:", pd.__version__)
print("Success!")
# Out:
# Pandas: 3.0.3
# Success!

# %%
with open("houses/cadata.txt", "r", encoding="latin1") as f:
    for i in range(40):
        print(i, f.readline())
# Out:
# 0 S&P Letters Data
#
# 1 We collected information on the variables using all the block groups in California from the 1990 Census. In this sample a block group on average includes 1425.5 individuals living in a geographically compact area. Naturally, the geographical area included varies inversely with the population density. We computed distances among the centroids of each block group as measured in latitude and longitude. We excluded all the block groups reporting zero entries for the independent and dependent variables. The final data contained 20,640 observations on 9 variables. The dependent variable is ln(median house value).
#
# 2
#
# 3 		Bols	tols
#
# 4 INTERCEPT		11.4939	275.7518
#
# 5 MEDIAN INCOME		0.4790	45.7768
#
# 6 MEDIAN INCOME2		-0.0166	-9.4841
#
# 7 MEDIAN INCOME3		-0.0002	-1.9157
#
# 8 ln(MEDIAN AGE)		0.1570	33.6123
#
# 9 ln(TOTAL ROOMS/ POPULATION)	-0.8582	-56.1280
#
# 10 ln(BEDROOMS/ POPULATION)	0.8043	38.0685
#
# 11 ln(POPULATION/ HOUSEHOLDS)	-0.4077	-20.8762
#
# ...

# %%
import pandas as pd

columns = [
    "MedHouseVal",
    "MedInc",
    "HouseAge",
    "TotalRooms",
    "TotalBedrooms",
    "Population",
    "Households",
    "Latitude",
    "Longitude"
]

df = pd.read_csv(
    "houses/cadata.txt",
    sep=r"\s+",
    skiprows=32,
    header=None,
    names=columns,
    encoding="latin1"
)

df.head()
# Out:
#    MedHouseVal  MedInc  HouseAge  TotalRooms  TotalBedrooms  Population  \
# 0     269700.0  4.0368      52.0       919.0          213.0       413.0
# 1     299200.0  3.6591      52.0      2535.0          489.0      1094.0
# 2     241400.0  3.1200      52.0      3104.0          687.0      1157.0
# 3     226700.0  2.0804      42.0      2555.0          665.0      1206.0
# 4     261100.0  3.6912      52.0      3549.0          707.0      1551.0
#
#    Households  Latitude  Longitude
# 0       193.0     37.85    -122.25
# 1       514.0     37.84    -122.25
# 2       647.0     37.84    -122.25
# 3       595.0     37.84    -122.26
# 4       714.0     37.84    -122.25

# %%
df.shape
# Out:
# (20635, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20635 entries, 0 to 20634
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MedHouseVal    20635 non-null  float64
#  1   MedInc         20635 non-null  float64
#  2   HouseAge       20635 non-null  float64
#  3   TotalRooms     20635 non-null  float64
#  4   TotalBedrooms  20635 non-null  float64
#  5   Population     20635 non-null  float64
#  6   Households     20635 non-null  float64
#  7   Latitude       20635 non-null  float64
#  8   Longitude      20635 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#          MedHouseVal        MedInc      HouseAge    TotalRooms  TotalBedrooms  \
# count   20635.000000  20635.000000  20635.000000  20635.000000   20635.000000
# mean   206816.445893      3.869992     28.635861   2635.803392     537.934335
# std    115380.007032      1.899362     12.583523   2181.576998     421.254693
# min     14999.000000      0.499900      1.000000      2.000000       1.000000
# 25%    119600.000000      2.562500     18.000000   1448.000000     296.000000
# 50%    179700.000000      3.534500     29.000000   2127.000000     435.000000
# 75%    264700.000000      4.742600     37.000000   3148.000000     647.000000
# max    500001.000000     15.000100     52.000000  39320.000000    6445.000000
#
#          Population    Households      Latitude     Longitude
# count  20635.000000  20635.000000  20635.000000  20635.000000
# mean    1425.611728    499.567725     35.631322   -119.569058
# std     1132.502473    382.326147      2.135930      2.003344
# ...

# %%
df.isnull().sum()
# Out:
# MedHouseVal      0
# MedInc           0
# HouseAge         0
# TotalRooms       0
# TotalBedrooms    0
# Population       0
# Households       0
# Latitude         0
# Longitude        0
# dtype: int64
